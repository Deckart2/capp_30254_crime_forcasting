# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import libpysal as lp

# %%
# %run geoprocessing_helpers.ipynb
# Out:
# ../raw_data/Boundaries - Police Beats (current).geojson EPSG:3435
# ../raw_data/Boundaries - Census Blocks - 2010.geojson EPSG:3435

# %%
crime_data = pd.read_csv("../intermediate_data/high_crime_labeled.csv")

# %%
beats = gpd.read_file("../raw_data/Boundaries - Police Beats (current).geojson")

# %%
crime_data["Beat"]=crime_data["Beat"].astype("string")
crime_data["Beat"] =crime_data["Beat"].str.zfill(4)

# %%
crime_data = beats.merge(crime_data, left_on="beat_num", right_on="Beat")

# %%
crime_data = compute_spatial_lag(crime_data, "high_crime", 
                                 "high_crime_geog_lag", 
                                 "Year")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/anaconda3/lib/python3.8/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/anaconda3/lib/python3.8/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/anaconda3/lib/python3.8/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/anaconda3/lib/python3.8/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# /opt/anaconda3/lib/python3.8/site-packages/geopandas/geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
crime_data.drop(columns = "geometry", axis=0)
# Out:
#       beat beat_num district sector  Year  Month   Watch  Beat  Crimes  \
# 0        1     1713       17      1  2015      1   First  1713      14
# 1        1     1713       17      1  2015      1  Second  1713      20
# 2        1     1713       17      1  2015      1   Third  1713      16
# 3        1     1713       17      1  2015      2   First  1713      10
# 4        1     1713       17      1  2015      2  Second  1713      12
# ...    ...      ...      ...    ...   ...    ...     ...   ...     ...
# 59088    1     0312       03      1  2020     11  Second  0312      21
# 59089    1     0312       03      1  2020     11   Third  0312      35
# 59090    1     0312       03      1  2020     12   First  0312      19
# 59091    1     0312       03      1  2020     12  Second  0312      18
# 59092    1     0312       03      1  2020     12   Third  0312      29
#
#        Arrest  ...  count_businesses  road_distance_ft  TOTAL POPULATION  \
# 0           2  ...              92.0     169276.405792      13283.675264
# 1           5  ...              92.0     169276.405792      13283.675264
# 2           5  ...              92.0     169276.405792      13283.675264
# 3           1  ...              92.0     169276.405792      13283.675264
# 4           1  ...              92.0     169276.405792      13283.675264
# ...       ...  ...               ...               ...               ...
# 59088       5  ...              38.0     200633.844449       4144.689546
# 59089       7  ...              38.0     200633.844449       4144.689546
# 59090       4  ...              38.0     200633.844449       4144.689546
# 59091       3  ...              38.0     200633.844449       4144.689546
# 59092       7  ...              38.0     200633.844449       4144.689546
#
#        dist_to_police  dist_to_hospital      SNOW       TMAX       TMIN  \
# 0         5454.068890       3258.006066  0.214286  33.785714  24.642857
# 1         5454.068890       3258.006066  0.344444  32.650000  23.000000
# 2         5454.068890       3258.006066  0.400000  31.812500  21.312500
# 3         5454.068890       3258.006066  0.320000  24.300000   8.400000
# 4         5454.068890       3258.006066  0.200000  22.666667   9.083333
# ...               ...               ...       ...        ...        ...
# 59088     4843.037238       4374.482421  0.038095  60.571429  42.095238
# 59089     4843.037238       4374.482421  0.000000  55.342857  38.000000
# 59090     4843.037238       4374.482421  0.000000  42.684211  29.368421
# 59091     4843.037238       4374.482421  0.177778  36.611111  26.666667
# 59092     4843.037238       4374.482421  0.113793  39.862069  27.517241
#
#        high_crime  high_crime_geog_lag
# 0             0.0             0.139442
# 1             0.0             0.139442
# 2             0.0             0.139442
# 3             0.0             0.139442
# 4             0.0             0.139442
# ...           ...                  ...
# 59088         0.0             0.177700
# 59089         0.0             0.177700
# 59090         0.0             0.177700
# 59091         0.0             0.177700
# 59092         0.0             0.177700
#
# [59093 rows x 29 columns]

# %%
crime_data.to_csv("../intermediate_data/high_crime_labeled.csv")
